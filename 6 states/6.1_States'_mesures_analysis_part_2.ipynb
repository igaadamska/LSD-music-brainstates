# %% [markdown]
# # Effect of LSD and music experience on brain states during resting state (8 states) #

# %% [markdown]
# This notebook is used for analysis of the effect of LSD and music experience on brain states during resting state.
#
# We calculate states' measures:
# 1) fractional occupancy
# 2) dwell time
# 3) transition probability
#
# Then, for each of these mesures we perform KS-tests to check if variables have a normal distirubtion. If so, we use t-test to test out hypothesis, otherise we use permutation non-parametric test.
#
# Number of states = 6
#
# **Last update:** 04.08.2022

# %% [markdown]
# ### Step 0: Loading libraries ####

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from nilearn import plotting
from nilearn.plotting import plot_matrix
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, norm, kstest
# %matplotlib inline
# !pip install mlxtend 
from mlxtend.evaluate import permutation_test
# Out:
# /home/iga/miniconda3/lib/python3.9/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "
# Requirement already satisfied: mlxtend in /home/iga/miniconda3/lib/python3.9/site-packages (0.19.0)
# Requirement already satisfied: scikit-learn>=0.20.3 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (1.0.1)
# Requirement already satisfied: joblib>=0.13.2 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: pandas>=0.24.2 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: numpy>=1.16.2 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (1.21.4)
# Requirement already satisfied: setuptools in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (52.0.0.post20210125)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (3.5.0)
# Requirement already satisfied: scipy>=1.2.1 in /home/iga/miniconda3/lib/python3.9/site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (21.0)
# Requirement already satisfied: setuptools-scm>=4 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (6.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.28.1)
# Requirement already satisfied: pytz>=2017.3 in /home/iga/miniconda3/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/iga/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from scikit-learn>=0.20.3->mlxtend) (3.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/iga/miniconda3/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib>=3.0.0->mlxtend) (1.2.2)

# %% [markdown]
# ### Step 1: Loading data ####

# %%
#Loading all data
df_merge = pd.read_csv('data/6_states/6_df_merge.csv')
data_r1_r3 = df_merge[df_merge['Run'] != 2]

# %% [markdown]
# ### Step 2: Plotting fractional occupancy for run 1 (resting state) and run 3 (resting state) ###

# %%
sns.catplot(x = 'Session', y = 'Fractional occupancy (%)', hue = 'Run', col = 'State', kind = 'bar', data = data_r1_r3,  height=4.5, aspect=0.7)
plt.savefig('Figures/fo_run13.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Step 3: Plotting dwell time for run 1 (resting state) and run 3 (resting state) ###

# %%
sns.catplot(x = 'Session', y = 'Dwell time (s)', hue = 'Run', col = 'State', kind = 'violin', data = data_r1_r3,  height=4.5, aspect=0.7)
plt.savefig('Figures/dt_run13.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## **Fractional occupancy analysis** ##

# %% [markdown]
# ### Step 4: Performing t-test for each state for fractional occupancy (run 1 vs run 3 for each session) ###

# %%
#Selecting states and sessions

sessions = ['PLCB', 'LSD']

iterator = np.arange(6) 

#Iterating over states and sessions
for i in iterator:
    for j in sessions:
        fo_state = data_r1_r3[(data_r1_r3['State'] == i+1) & (data_r1_r3['Session'] == j)]
        fo_run1 = []
        fo_run3 = []
        for index, row in fo_state.iterrows():
            if row['Run'] == 1:
                fo_run1.append(row['Fractional occupancy (%)'])
            else:
                fo_run3.append(row['Fractional occupancy (%)'])
                
        stat_t, pval_t = ttest_rel(fo_run1, fo_run3) #Calculating paired t-test
        print(f'Paired T-test for state {i+1}, session {j} | statistics: {stat_t}, p-value: {pval_t}')
        print('')
# Out:
# Paired T-test for state 1, session PLCB | statistics: 0.3031562631918931, p-value: 0.7662288543214921
#
# Paired T-test for state 1, session LSD | statistics: 0.287997366893254, p-value: 0.7775683004295749
#
# Paired T-test for state 2, session PLCB | statistics: -0.0404320431930902, p-value: 0.9683196269908845
#
# Paired T-test for state 2, session LSD | statistics: 0.16003247635757045, p-value: 0.8751415197279093
#
# Paired T-test for state 3, session PLCB | statistics: -1.0474494064475652, p-value: 0.3126399952690666
#
# Paired T-test for state 3, session LSD | statistics: -0.7834907868404554, p-value: 0.4463918998375833
#
# Paired T-test for state 4, session PLCB | statistics: 0.0957408111752095, p-value: 0.9250833766446146
#
# Paired T-test for state 4, session LSD | statistics: 0.38925276326049063, p-value: 0.7029457410869663
#
# Paired T-test for state 5, session PLCB | statistics: 1.074454934632295, p-value: 0.3007888864660035
#
# Paired T-test for state 5, session LSD | statistics: 1.0779993111012522, p-value: 0.29925843218090087
#
# Paired T-test for state 6, session PLCB | statistics: -1.1851219951290692, p-value: 0.25569693862306864
#
# Paired T-test for state 6, session LSD | statistics: -1.264347004779864, p-value: 0.2267500165292754

# %% [markdown]
# ### Step 5: Performing t-test for each state for fractional occupancy (difference between run 3 and run 1) ###

# %%
#Iterating over states and sessions
for i in iterator:
    diff_list = []
    for j in sessions:
        fo_state = data_r1_r3[(data_r1_r3['State'] == i+1) & (data_r1_r3['Session'] == j)]
        fo_run1 = []
        fo_run3 = []
        
        for index, row in fo_state.iterrows():
            if row['Run'] == 1:
                fo_run1.append(row['Fractional occupancy (%)'])
            else:
                fo_run3.append(row['Fractional occupancy (%)'])
                
        diff = np.array(fo_run3) - np.array(fo_run1) #Calculating the difference between run 3 and run 1
        diff_list.append(diff)
        
    stat_t, pval_t = ttest_rel(diff_list[0], diff_list[1]) #Calculating paired t-test
    print(f'Paired T-test for state {i+1} | statistics: {stat_t}, p-value: {pval_t}')
    print('')
# Out:
# Paired T-test for state 1 | statistics: 0.13034681147667543, p-value: 0.8981464419928282
#
# Paired T-test for state 2 | statistics: 0.14847218449416538, p-value: 0.88408747115112
#
# Paired T-test for state 3 | statistics: 0.11525073729836964, p-value: 0.9098831030388725
#
# Paired T-test for state 4 | statistics: 0.28428339998981533, p-value: 0.7803546491767916
#
# Paired T-test for state 5 | statistics: -0.3675013763959651, p-value: 0.7187411375524178
#
# Paired T-test for state 6 | statistics: -0.264972888982415, p-value: 0.7948917730917807

# %% [markdown]
# ### Step 6: Performing t-test for run 3 for fractional occupancy (placebo vs LSD for each run) ###

# %%
#Selecting runs
runs = [3]

#Iterating over states and runs
for i in iterator:
    fo_plcb = []
    fo_lsd = []
    for j in runs:
        fo_run = data_r1_r3[data_r1_r3['Run'] == j]
        for index, row in fo_run.iterrows():
            if row['State'] == i+1:
                if row['Session'] == 'PLCB':
                    fo_plcb.append(row['Fractional occupancy (%)'])
                else:
                    fo_lsd.append(row['Fractional occupancy (%)'])
                    
        stat_t, pval_t = ttest_rel(fo_plcb, fo_lsd) #Calculating paired t-test
        print(f'Paired T-test for run {j}, state {i+1}| statistics: {stat_t}, p-value: {pval_t}')
        print('')
# Out:
# Paired T-test for run 3, state 1| statistics: 0.7601717984949309, p-value: 0.45976296539926154
#
# Paired T-test for run 3, state 2| statistics: -0.89910134775393, p-value: 0.3838024761827862
#
# Paired T-test for run 3, state 3| statistics: 0.5434539169369413, p-value: 0.5953655062090348
#
# Paired T-test for run 3, state 4| statistics: 0.029384542507066843, p-value: 0.9769726833134948
#
# Paired T-test for run 3, state 5| statistics: -0.8175816826966041, p-value: 0.42729180589086846
#
# Paired T-test for run 3, state 6| statistics: 1.1183396991841053, p-value: 0.2822448994867809

# %% [markdown]
# ## **Dwell time analysis** ##

# %% [markdown]
# ### Step 7: Performing t-test for each state for dwell time (run 1 vs run 3 for each session) ###

# %%
#Iterating over states and sessions
for i in iterator:
    for j in sessions:
        dt_state = data_r1_r3[(data_r1_r3['State'] == i+1) & (data_r1_r3['Session'] == j)]
        dt_run1 = []
        dt_run3 = []
        for index, row in dt_state.iterrows():
            if row['Run'] == 1:
                dt_run1.append(row['Dwell time (s)'])
            else:
                dt_run3.append(row['Dwell time (s)'])
                
        stat_t, pval_t = ttest_rel(dt_run1, dt_run3) #Calculating paired t-test
        print(f'Paired T-test for state {i+1}, session {j} | statistics: {stat_t}, p-value: {pval_t}')
        print('')
# Out:
# Paired T-test for state 1, session PLCB | statistics: 1.023168507015463, p-value: 0.3235837468697219
#
# Paired T-test for state 1, session LSD | statistics: 0.5868803231177829, p-value: 0.5666283352776291
#
# Paired T-test for state 2, session PLCB | statistics: 0.43643179499752394, p-value: 0.6691787780095104
#
# Paired T-test for state 2, session LSD | statistics: -0.2635684056082613, p-value: 0.7959522463946961
#
# Paired T-test for state 3, session PLCB | statistics: -0.6738173145514716, p-value: 0.5113997758617491
#
# Paired T-test for state 3, session LSD | statistics: -0.2750121968611432, p-value: 0.7873238354434049
#
# Paired T-test for state 4, session PLCB | statistics: 0.3083315322387121, p-value: 0.7623700973395148
#
# Paired T-test for state 4, session LSD | statistics: -0.9411509028726229, p-value: 0.3625845740309158
#
# Paired T-test for state 5, session PLCB | statistics: 0.816218203377187, p-value: 0.42804545327081156
#
# Paired T-test for state 5, session LSD | statistics: 1.1861254409396322, p-value: 0.2553132013151549
#
# Paired T-test for state 6, session PLCB | statistics: -1.4850977325682533, p-value: 0.15968437541902658
#
# Paired T-test for state 6, session LSD | statistics: 1.0093478288281519, p-value: 0.3299353982346016

# %% [markdown]
# ### Step 8: Performing t-test for each state for dwell time (difference between run 3 and run 1) ###

# %%
for i in iterator:
    diff_list = []
    for j in sessions:
        dt_state = data_r1_r3[(data_r1_r3['State'] == i+1) & (data_r1_r3['Session'] == j)]
        dt_run1 = []
        dt_run3 = []
        for index, row in dt_state.iterrows():
            if row['Run'] == 1:
                dt_run1.append(row['Dwell time (s)'])
            else:
                dt_run3.append(row['Dwell time (s)'])
                
        diff = np.array(dt_run3) - np.array(dt_run1)
        diff_list.append(diff)
        
    stat_t, pval_t = ttest_rel(diff_list[0], diff_list[1]) #Calculating paired t-test
    print(f'Paired T-test for state {i+1} | statistics: {stat_t}, p-value: {pval_t}')
    print('')
# Out:
# Paired T-test for state 1 | statistics: -0.050268396921041736, p-value: 0.9606186616950528
#
# Paired T-test for state 2 | statistics: -0.48279280925789886, p-value: 0.636704965639945
#
# Paired T-test for state 3 | statistics: 0.19218186833885084, p-value: 0.8503594672401235
#
# Paired T-test for state 4 | statistics: -0.8834772557879691, p-value: 0.39189747129436936
#
# Paired T-test for state 5 | statistics: 0.04956033110567805, p-value: 0.9611728857525715
#
# Paired T-test for state 6 | statistics: 1.9399966087642588, p-value: 0.07279648951668163

# %% [markdown]
# ### Step 9: Performing t-test for run 3 for dwell time (placebo vs LSD for each run) ###

# %%
runs = [3]

#Iterating over states and runs
for i in iterator:
    dt_plcb = []
    dt_lsd = []
    for j in runs:
        dt_run = data_r1_r3[data_r1_r3['Run'] == j]
        for index, row in dt_run.iterrows():
            if row['State'] == i+1:
                if row['Session'] == 'PLCB':
                    dt_plcb.append(row['Dwell time (s)'])
                else:
                    dt_lsd.append(row['Dwell time (s)'])
                    
        stat_t, pval_t = ttest_rel(dt_plcb, dt_lsd) #Calculating paired t-test
        print(f'Paired T-test for run {j}, state {i+1}| statistics: {stat_t}, p-value: {pval_t}')
        print('')
# Out:
# Paired T-test for run 3, state 1| statistics: -0.1792058088363756, p-value: 0.8603437846117512
#
# Paired T-test for run 3, state 2| statistics: -1.5300473804805137, p-value: 0.14828287306862117
#
# Paired T-test for run 3, state 3| statistics: 0.051123045615737876, p-value: 0.959949731055642
#
# Paired T-test for run 3, state 4| statistics: -1.3869555450793256, p-value: 0.1871422902780639
#
# Paired T-test for run 3, state 5| statistics: -0.005009538006532915, p-value: 0.9960736673870548
#
# Paired T-test for run 3, state 6| statistics: 0.9614835558843414, p-value: 0.3526223779123765

# %% [markdown]
# ## **Transition probability analysis** ##

# %% [markdown]
# ### Step 10: Loading data ###

# %%
#Loading all data
bs_all = np.load('data/fixed_brain_states_reshaped.npy', allow_pickle = True).item()

#Loading data for each session (placebo / LSD) and run (rest 1 / rest 2 )
bs_plcb_run1 = bs_all['PLCB']['run_1'][4,:,:]
bs_plcb_run3 = bs_all['PLCB']['run_3'][4,:,:]

bs_lsd_run1 = bs_all['LSD']['run_1'][4,:,:]
bs_lsd_run3 = bs_all['LSD']['run_3'][4,:,:]

# %% [markdown]
# ### Step 11: Calculating transition probability for placebo session ###

# %%
states_no = 6

plcb_all = [bs_plcb_run1, bs_plcb_run3]
state_transitions_plcb = np.zeros((bs_plcb_run1.shape[0], 2, states_no, states_no))

for s, bs in enumerate(plcb_all):
    for sub in range(bs.shape[0]):   
            for i in range(states_no):
                for j in range(states_no):
                    count = 0
                    for l in range(bs.shape[1]-1):
                        if bs[sub, l] == i and bs[sub, l+1] == j:
                            count += 1
                            p = count/np.unique(bs[sub, :], return_counts=True)[1][i] #Calculating transition probability
                    state_transitions_plcb[sub, s, i, j] = p
                    
np.save('data/6_states/state_transitions_plcb_2.npy', state_transitions_plcb)

# %% [markdown]
# ### Step 12: KS-test for transition probability for placebo session run 1 & 3 ###

# %% [markdown]
# #### Step 12.1: KS-test for transition probability, placebo session run 1

# %%
plcb_run1 = state_transitions_plcb[:,0,:,:]

p1_trans1 = np.concatenate(plcb_run1, axis = 0)
plcb1 = np.concatenate(p1_trans1, axis = 0)

p1_loc, p1_scale = norm.fit(plcb1)
n1 = norm(loc=p1_loc, scale=p1_scale)
p1_stat, p1_pval = kstest(plcb1, n1.cdf)
print(f'KS-test for transition probability, placebo session, run 1: statistics {p1_stat}, p-value {p1_pval}')

plt.hist(plcb1, bins=np.arange(plcb1.min(), plcb1.max()+0.2, 0.2), rwidth=0.5)
p1_x = np.arange(plcb1.min(), plcb1.max()+0.2, 0.2)
plt.plot(p1_x, 120*n1.pdf(p1_x))
plt.title('Transition probability placebo, run 1 distibution')
plt.show()diff_mm_diff_mean
# Out:
# KS-test for transition probability, placebo session, run 1: statistics 0.3195511701657243, p-value 1.5170842528971242e-49

# %% [markdown]
# #### Step 12.2: KS-test for transition probability, placebo session run 3

# %%
plcb_run3 = state_transitions_plcb[:,1,:,:]

p3_trans1 = np.concatenate(plcb_run3, axis = 0)
plcb3 = np.concatenate(p3_trans1, axis = 0)

p3_loc, p3_scale = norm.fit(plcb3)
n3 = norm(loc=p3_loc, scale=p3_scale)
p3_stat, p3_pval = kstest(plcb3, n3.cdf)
print(f'KS-test for transition probability, placebo session, run 3: statistics {p3_stat}, p-value {p3_pval}')

plt.hist(plcb3, bins=np.arange(plcb3.min(), plcb3.max()+0.2, 0.2), rwidth=0.5)
p3_x = np.arange(plcb3.min(), plcb3.max()+0.2, 0.2)
plt.plot(p3_x, 120*n3.pdf(p3_x))
plt.title('Transition probability placebo, run 3 distibution')
plt.show()
# Out:
# KS-test for transition probability, placebo session, run 3: statistics 0.29355522625891894, p-value 1.0003281221878709e-41

# %% [markdown]
# ### Step 13: Performing permutation test for placebo session between run 1 and run 3 ###

# %%
#Creating empty matrices to store the data
plcb_mm_diff_mean = np.zeros((6,6))
plcb_mm_pval = np.zeros((6,6))

#Calculating mean difference and p-value
for i in range(6):
    for j in range(6):
        diff_mean = np.mean(state_transitions_plcb[:,1,i,j] - state_transitions_plcb[:,0,i,j])
        plcb_mm_diff_mean[i,j] = diff_mean
        p_value = permutation_test(state_transitions_plcb[:,1,i,j], state_transitions_plcb[:,0,i,j], method = 'approximate', num_rounds = 10000, seed = 0, paired = True)
        plcb_mm_pval[i,j] = round(p_value, 10)
        
#Plotting statistics
plt.figure(figsize=(10,7))
plcb_ttest = sns.heatmap(plcb_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, annot = plcb_mm_pval[:, :], xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6])
plt.savefig(f'Figures/6_states/tp_plcb_run13_annot.png', dpi=300, bbox_inches='tight')

#Plotting statistics
plt.figure(figsize=(10,7))
plcb_ttest = sns.heatmap(plcb_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6], vmin=-0.1, vmax=0.1)
plt.savefig(f'Figures/6_states/tp_plcb_run13.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Step 14: Calculating transition probability for LSD session ###

# %%
lsd_all = [bs_lsd_run1, bs_lsd_run3]
state_transitions_lsd = np.zeros((bs_lsd_run1.shape[0], 2, states_no, states_no))


for s, bs in enumerate(lsd_all):
    for sub in range(bs.shape[0]):   
            for i in range(states_no):
                for j in range(states_no):
                    count = 0
                    for l in range(bs.shape[1]-1):
                        if bs[sub, l] == i and bs[sub, l+1] == j:
                            count += 1
                            p = count/np.unique(bs[sub, :], return_counts=True)[1][i] #Calculating transition probability
                    state_transitions_lsd[sub, s, i, j] = p
                    
np.save('data/6_states/state_transitions_lsd_2.npy', state_transitions_lsd)

# %% [markdown]
# ### Step 15: KS-test for transition probability for LSD session run 1 & 3 ###

# %% [markdown]
# #### Step 15.1: KS-test transition probability LSD session run 1 #####

# %%
lsd_run1 = state_transitions_lsd[:,0,:,:]

l1_trans1 = np.concatenate(lsd_run1, axis = 0)
lsd1 = np.concatenate(l1_trans1, axis = 0)

l1_loc, l1_scale = norm.fit(lsd1)
n1 = norm(loc=l1_loc, scale=l1_scale)
l1_stat, l1_pval = kstest(lsd1, n1.cdf)
print(f'KS-test for transition probability, LSD session, run 1: statistics {l1_stat}, p-value {l1_pval}')

plt.hist(lsd1, bins=np.arange(lsd1.min(), lsd1.max()+0.2, 0.2), rwidth=0.5)
l1_x = np.arange(lsd1.min(), lsd1.max()+0.2, 0.2)
plt.plot(l1_x, 120*n1.pdf(l1_x))
plt.title('Transition probability LSD, run 1 distibution')
plt.show()
# Out:
# KS-test for transition probability, LSD session, run 1: statistics 0.2929520362568926, p-value 1.4893841495994908e-41

# %% [markdown]
# #### Step 15.2: KS-test transition probability LSD session run 3 ####

# %%
lsd_run3 = state_transitions_lsd[:,1,:,:]

l3_trans1 = np.concatenate(lsd_run3, axis = 0)
lsd3 = np.concatenate(l3_trans1, axis = 0)

l3_loc, l3_scale = norm.fit(lsd3)
n3 = norm(loc=l3_loc, scale=l3_scale)
l3_stat, l3_pval = kstest(lsd3, n3.cdf)
print(f'KS-test for transition probability, LSD session, run 3: statistics {l3_stat}, p-value {l3_pval}')

plt.hist(lsd3, bins=np.arange(lsd3.min(), lsd3.max()+0.2, 0.2), rwidth=0.5)
l3_x = np.arange(lsd3.min(), lsd3.max()+0.2, 0.2)
plt.plot(l3_x, 120*n3.pdf(l3_x))
plt.title('Transition probability LSD, run 3 distibution')
plt.show()
# Out:
# KS-test for transition probability, LSD session, run 3: statistics 0.3232225636189665, p-value 1.0423665688106232e-50

# %% [markdown]
# ### Step 16: Performing permutation for LSD session between run 1 and run 3 ###

# %%
#Creating empty matrices to store the data
lsd_mm_diff_mean = np.zeros((6,6))
lsd_mm_pval = np.zeros((6,6))

#Calculating mean difference and p-value
for i in range(6):
    for j in range(6):
        diff_mean = np.mean(state_transitions_lsd[:,1,i,j] - state_transitions_lsd[:,0,i,j])
        lsd_mm_diff_mean[i,j] = diff_mean
        p_value = permutation_test(state_transitions_lsd[:,1,i,j], state_transitions_lsd[:,0,i,j], method = 'approximate', num_rounds = 10000, seed = 0, paired = True)
        lsd_mm_pval[i,j] = round(p_value, 10)
        
#Plotting statistics
plt.figure(figsize=(10,7))
lsd_ttest = sns.heatmap(lsd_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, annot = lsd_mm_pval[:, :], xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6])
plt.savefig(f'Figures/6_states/tp_lsd_run13_annot.png', dpi=300, bbox_inches='tight')

#Plotting statistics
plt.figure(figsize=(10,7))
lsd_ttest = sns.heatmap(lsd_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6], vmin=-0.1, vmax=0.1)
plt.savefig(f'Figures/6_states/tp_lsd_run13.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Step 17: Performing permutation test for run 3 between LSD and placebo session ###

# %%
#Creating empty matrices to store the data
run3_mm_diff_mean = np.zeros((6,6))
run3_mm_pval = np.zeros((6,6))

#Calculating mean difference and p-value
for i in range(6):
    for j in range(6):
        diff_mean = np.mean(state_transitions_lsd[:,1,i,j] - state_transitions_plcb[:,1,i,j])
        run3_mm_diff_mean[i,j] = diff_mean
        p_value = permutation_test(state_transitions_lsd[:,1,i,j], state_transitions_plcb[:,1,i,j], method = 'approximate', num_rounds = 10000, seed = 0, paired = True)
        run3_mm_pval[i,j] = round(p_value, 10)
        
#Plotting statistics
plt.figure(figsize=(10,7))
run2_ttest = sns.heatmap(run3_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, annot = run3_mm_pval[:, :], xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6])
plt.savefig(f'Figures/6_states/tp_lsd-plcb_run3_annot.png', dpi=300, bbox_inches='tight')

#Plotting statistics
plt.figure(figsize=(10,7))
run2_ttest = sns.heatmap(run3_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6], vmin=-0.1, vmax=0.1)
plt.savefig(f'Figures/6_states/tp_lsd-plcb_run3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Step 18: Performing permutation test for differences in both sessions between run 3 and run 1 ###

# %%
#Calculating difference for placebo session
plcb_difference = state_transitions_plcb[:,1,:,:] - state_transitions_plcb[:,0,:,:]

#Calculating difference for LSD session
lsd_difference = state_transitions_lsd[:,1,:,:] - state_transitions_lsd[:,0,:,:]

plot_matrix(plcb_difference.mean(axis=0), title = 'Difference for plcb session', vmin = 0.0, vmax=0.6)
plot_matrix(lsd_difference.mean(axis=0), title = 'Difference for LSD session', vmin = 0.0, vmax=0.6)


#Creating empty matrices to store the data
diff_mm_diff_mean = np.zeros((6,6))
diff_mm_pval = np.zeros((6,6))

#Calculating mean difference and p-value
for i in range(6):
    for j in range(6):
        diff_mean = np.mean(lsd_difference[:,i,j] - plcb_difference[:,i,j])
        diff_mm_diff_mean[i,j] = diff_mean
        p_value = permutation_test(lsd_difference[:,i,j], plcb_difference[:,i,j], method = 'approximate', num_rounds = 10000, seed = 0, paired = True)
        diff_mm_pval[i,j] = round(p_value, 10)
        
#Plotting statistics
plt.figure(figsize=(10,7))
diff_ttest = sns.heatmap(diff_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, annot = diff_mm_diff_mean[:, :], xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6])
plt.savefig(f'Figures/6_states/tp_lsd-plcb_diff_run13_annot.png', dpi=300, bbox_inches='tight')

#Plotting statistics
plt.figure(figsize=(10,7))
diff_ttest = sns.heatmap(diff_mm_diff_mean, square = True, cmap = "RdBu_r", cbar= True, xticklabels = [1,2,3,4,5,6], yticklabels = [1,2,3,4,5,6], vmin=-0.1, vmax=0.1)
plt.savefig(f'Figures/6_states/tp_lsd-plcb_diff_run13.png', dpi=300, bbox_inches='tight')
